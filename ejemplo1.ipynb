# %% [markdown]
# <a href="https://colab.research.google.com/github/TapAndre/Python20261/blob/main/ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
print("Andree Mejia")
# Out:
# hola mundo
# Andree Mejia

# %%
print('hola mundo')
# Out:
# hola mundo

# %% [markdown]
# # texto 1 **texto 1 en negrita**

# %%
print("26 de Enero de 2026")
# Out:
# 26 de Enero de 2026

# %%
edad=int(input("Ingresa tu edad:"))
print("Tu edad es:", edad)
# Out:
# Ingresa tu edad:22
# Tu edad es: 22
